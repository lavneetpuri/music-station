# %%
import sys
import pandas as pd
import numpy as np
from data.main import songs

# %%
songs = songs.sample(5)
songs
# Out:
#                 track_id                                title  \
# 7524  TRAVWIP128E078FA3D                          Family Tree
# 2901  TRAAKSB128F934D73A                                Festa
# 6210  TRATJXZ128F9310ADB                            Nom' Mayi
# 8420  TRBAYOQ128F14A8744  Jesus Loves Me (Now More Than Ever)
# 232   TRACWCG128F9344150              Fall Away Into Darkness
#
#                artist_id  year    tempo  song_hotttnesss  mode  \
# 7524  AR1ZYLH1187B98C159  2002   93.502              NaN     0
# 2901  AREEMIN11F4C848971     0  150.666         0.392009     1
# 6210  AR49IWV1187FB3C663     0   98.180              NaN     1
# 8420  ARG274E1187FB4BCA8     0  146.622         0.531722     1
# 232   AR573WK1187FB47167  2007  116.423              NaN     1
#
#       mode_confidence  key  key_confidence  loudness  energy   duration  \
# 7524            0.386   11           0.108    -3.831     0.0  330.08281
# ...

# %%
med_song = songs.median()
med_song
# Out:
# year                        0.000000
# tempo                     116.423000
# song_hotttnesss             0.461865
# mode                        1.000000
# mode_confidence             0.386000
# key                         9.000000
# key_confidence              0.108000
# loudness                   -9.412000
# energy                      0.000000
# duration                  285.361180
# danceability                0.000000
# end_of_fade_in              0.166000
# start_of_fade_out         264.452000
# analysis_sample_rate    22050.000000
# dtype: float64
